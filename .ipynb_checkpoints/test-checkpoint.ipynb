# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from utils import *

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

plt.rcParams['font.sans-serif'] = ['KaiTi', 'SimHei', 'FangSong']  # 汉字字体,优先使用楷体，如果找不到楷体，则使用黑体
plt.rcParams['font.size'] = 12  # 字体大小
plt.rcParams['axes.unicode_minus'] = False  # 正常显示负号

keys = ['采集时间', '水温', 'pH', '溶解氧', '电导率', '浊度', '高锰酸盐指数', '氨氮', '总磷', '总氮']
ks = ['date', 'water temperature', 'PH' ,'dissolved oxygen', 'Conductivity','Turbidity','PermanganateIndex',
        'Ammonia nitrogen','total phosphorus','total nitrogen', 'humidity','room temperature','chlorophyll','Algae density']
# data = pd.read_csv('./data0.csv')
# data['时间'] = pd.to_datetime(arg=data['时间'], format='%Y-%m-%d %H:%M:%S')
# data = data.set_index(data.columns[0])
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# insert middle values by the mean values
days = data.shape[0]//6
keys = data.keys()
for k in keys:
    vals = data[k].values
    for i in range(0, days):
        one_day_vals = vals[i*6: (i+1)*6]
        mean = np.mean(one_day_vals)
        for j in range(6):
            idx = i*6 + j
            if vals[j] == 0:
                data[k][idx] = mean
#         if np.isnan(val0) and not np.isnan(val1) and not np.isnan(val2):
#             print(f'{k} {i}')
#             data[k][i] = (val1 + val2)/2

# %%
myFilter(data, labels=list(data.keys()), name='./data0.csv')
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# True

# %%
excel_path = './original_data.xls'
def dataClean(excel_path, header=2, labels=['采集时间', '水温', 'pH', '溶解氧', '电导率', '浊度', '高锰酸盐指数', '氨氮', '总磷', '总氮']):
    # Read the original data and copy one.
    # 'Date' is default as the first colume.
    df = pd.read_excel(excel_path, header=2, usecols=labels).copy()
    df.set_index(labels[0], inplace=True)
    # Clean the wrong data type and labeled them as 'None'
    for k in df.keys():
        df[k].mask(df[k] == '--', None, inplace=True)
    df = df.astype('float16')
        
#     Clean the strange data point
    for k in :
        vals = pd.Series(df[k].values.copy())
        out_idxs = compute_zscore(df, k)
        vals[out_idxs] = None
        df[k] = vals
    return df

# %%
df = dataClean(excel_path)
df.dtypes
# Out:
# /home/zxpwhu/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/zxpwhu/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:212: RuntimeWarning: overflow encountered in reduce
#   arrmean = umr_sum(arr, axis, dtype, keepdims=True, where=where)
# /home/zxpwhu/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:233: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1085, in Series.__setitem__(self, key, value)
#    1084 try:
# -> 1085     self._set_with_engine(key, value)
#    1086 except (KeyError, ValueError):
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1146, in Series._set_with_engine(self, key, value)
#    1145 def _set_with_engine(self, key, value) -> None:
# -> 1146     loc = self.index.get_loc(key)
#    1148     # this is equivalent to self._values[key] = value
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/range.py:388, in RangeIndex.get_loc(self, key, method, tolerance)
#     387         raise KeyError(key) from err
# --> 388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5637, in Index._check_indexing_error(self, key)
#    5634 if not is_scalar(key):
#    5635     # if key is not a scalar, directly raise an error (the code below
#    5636     # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637     raise InvalidIndexError(key)
#
# InvalidIndexError: Index(['2021-11-15 04:00:00', '2021-11-12 20:00:00', '2021-06-09 00:00:00',
#        '2021-04-24 08:00:00', '2021-03-23 20:00:00', '2021-03-20 16:00:00',
#        '2021-02-06 12:00:00', '2021-02-05 08:00:00', '2021-01-13 09:00:00',
#        '2020-11-27 08:00:00', '2020-11-22 20:00:00', '2020-10-21 08:00:00',
#        '2020-08-24 16:00:00', '2020-08-09 16:00:00', '2020-07-30 08:00:00',
#        '2020-07-15 08:00:00', '2020-06-18 08:00:00', '2020-06-15 04:00:00',
#        '2020-06-08 00:00:00', '2020-05-29 12:00:00', '2020-05-14 00:00:00',
#        '2020-05-03 04:00:00', '2020-04-16 20:00:00', '2020-04-04 16:00:00',
#        '2020-03-19 00:00:00', '2020-02-03 08:00:00', '2020-02-03 04:00:00',
#        '2020-01-27 04:00:00', '2020-01-02 12:00:00', '2019-12-15 12:00:00',
#        '2019-11-05 16:00:00', '2019-10-11 12:00:00', '2019-09-30 04:00:00',
#        '2019-09-18 08:00:00', '2019-08-29 12:00:00', '2019-08-13 00:00:00',
#        '2019-07-25 16:00:00', '2019-07-17 12:00:00', '2019-07-04 12:00:00',
#        '2019-06-18 12:00:00', '2019-04-26 12:00:00', '2019-04-19 00:00:00',
#        '2019-04-08 00:00:00', '2019-04-01 20:00:00', '2019-03-12 12:00:00',
#        '2019-03-07 12:00:00', '2019-02-16 00:00:00', '2019-01-03 12:00:00',
#        '2018-11-12 20:00:00', '2018-10-27 16:00:00', '2018-10-25 20:00:00',
#        '2018-09-16 20:00:00', '2018-08-30 16:00:00', '2018-08-29 12:00:00',
#        '2018-03-18 12:00:00', '2018-03-18 08:00:00'],
#       dtype='object', name='采集时间')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 df = dataClean(excel_path)
#       2 df.dtypes
#
# Input In [34], in dataClean(excel_path, header, labels)
#      14     vals = pd.Series(df[k].values.copy())
#      15     out_idxs = compute_zscore(df, k)
# ---> 16     vals[out_idxs] = None
#      17     df[k] = vals
#      18 return df
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1140, in Series.__setitem__(self, key, value)
#    1137         return
#    1139     else:
# -> 1140         self._set_with(key, value)
#    1142 if cacher_needs_updating:
#    1143     self._maybe_update_cacher()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1171, in Series._set_with(self, key, value)
#    1169         self._set_values(key, value)
#    1170 else:
# -> 1171     self.loc[key] = value
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:712, in _LocationIndexer.__setitem__(self, key, value)
#     710 else:
#     711     key = com.apply_if_callable(key, self.obj)
# --> 712 indexer = self._get_setitem_indexer(key)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:666, in _LocationIndexer._get_setitem_indexer(self, key)
#     663 if isinstance(key, range):
#     664     return list(key)
# --> 666 return self._convert_to_indexer(key, axis=0)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1291, in _LocIndexer._convert_to_indexer(self, key, axis)
#    1289         return inds
#    1290     else:
# -> 1291         return self._get_listlike_indexer(key, axis)[1]
#    1292 else:
#    1293     try:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1327, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1324 ax = self.obj._get_axis(axis)
#    1325 axis_name = self.obj._get_axis_name(axis)
# -> 1327 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1329 return keyarr, indexer
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['2021-11-15 04:00:00', '2021-11-12 20:00:00', '2021-06-09 00:00:00',\n       '2021-04-24 08:00:00', '2021-03-23 20:00:00', '2021-03-20 16:00:00',\n       '2021-02-06 12:00:00', '2021-02-05 08:00:00', '2021-01-13 09:00:00',\n       '2020-11-27 08:00:00', '2020-11-22 20:00:00', '2020-10-21 08:00:00',\n       '2020-08-24 16:00:00', '2020-08-09 16:00:00', '2020-07-30 08:00:00',\n       '2020-07-15 08:00:00', '2020-06-18 08:00:00', '2020-06-15 04:00:00',\n       '2020-06-08 00:00:00', '2020-05-29 12:00:00', '2020-05-14 00:00:00',\n       '2020-05-03 04:00:00', '2020-04-16 20:00:00', '2020-04-04 16:00:00',\n       '2020-03-19 00:00:00', '2020-02-03 08:00:00', '2020-02-03 04:00:00',\n       '2020-01-27 04:00:00', '2020-01-02 12:00:00', '2019-12-15 12:00:00',\n       '2019-11-05 16:00:00', '2019-10-11 12:00:00', '2019-09-30 04:00:00',\n       '2019-09-18 08:00:00', '2019-08-29 12:00:00', '2019-08-13 00:00:00',\n       '2019-07-25 16:00:00', '2019-07-17 12:00:00', '2019-07-04 12:00:00',\n       '2019-06-18 12:00:00', '2019-04-26 12:00:00', '2019-04-19 00:00:00',\n       '2019-04-08 00:00:00', '2019-04-01 20:00:00', '2019-03-12 12:00:00',\n       '2019-03-07 12:00:00', '2019-02-16 00:00:00', '2019-01-03 12:00:00',\n       '2018-11-12 20:00:00', '2018-10-27 16:00:00', '2018-10-25 20:00:00',\n       '2018-09-16 20:00:00', '2018-08-30 16:00:00', '2018-08-29 12:00:00',\n       '2018-03-18 12:00:00', '2018-03-18 08:00:00'],\n      dtype='object', name='采集时间')] are in the [index]"

# %%
features_num = len(data.keys())
figure, axis = plt.subplots(features_num, 1, 
                        figsize=(20, features_num*10))
# X = np.linspace(0, 1, data.shape[0])
for i in range(features_num):
    name = data.keys()[i]
    vals = data[name].values
    X = np.linspace(0, 1, len(vals))
    axis[i].plot(X, vals)
    axis[i].set_title(f"{ks[i]}")
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: KaiTi, SimHei, FangSong
